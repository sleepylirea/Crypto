# %% [markdown]
# # Fonction

# %%
def compter(text):
    # text = text.lower()
    d = {}
    for i in range (len(text)):
        if text[i] not in d :
            d[text[i]]=0
        d[text[i]]+=1
    return d

def compter_occurences(c, text) :
    # text = text.lower()
    x = 0
    for i in range (len(text)):
        if c == text[i]:
            x += 1
    return c, x

def substituer(a, Na, t) :
    t = t.lower()
    L = list(t)
    for i in range (len(L)) :
        if L[i] == a :
            L[i] = Na
    T = ''.join(L)
    return T

def decaler(c, d):
    c = chr(ord(c)+d)
    return c

def chiffrement_cesar(t, d):
    L = list(t)
    for i in range (len(L)) :
        L[i] = decaler(L[i], d)
    T = ''.join(L)
    return (T,d)

def dechiffrement_cesar(t, d):
    L = list(t)
    for i in range (len(L)) :
        L[i] = decaler(L[i], (-d))
    T = ''.join(L)
    return T

def couper(p, n, t) :    # p = parti   n = numéro dans la partie
    L = list(t)
    if len(L)/p != (len(L)//p) :
        for i in range (len(L)%p) :
            L.append('')
    T = []
    for i in range (len(L)) :
        if i%p == n :
            T.append(L[(i)])
    T = ''.join(T)
    return T

def assembler(L):
    T = []
    n = len(L)
    for i in range (len(L[n-1])) :
        for j in range (n) :
            T.append(L[j][i])
    for loop in range (n) :
        if len(L[0]) == len(L[loop]) :
            T.append(L[loop][len(L[n-1])])
    T = ''.join(T)
    return T

def complet (t, p):        # text   parti   
    T = []
    for i in range (p) :
        T.append(couper(p,i,t))
    for i in range (p) :
        D = compter(T[i])
        a = 0
        b = ''
        for k,v in D.items() :
            if v > a :
                a = v
                b = k
        d = ord(b)-ord(' ')
        T[i] = dechiffrement_cesar(T[i], d)
    return assembler(T)

# %%
def cryptDecrypt (M,n) :
    if n != 0 :
        L = list(M)
        for i in range (len(L)) :
            L[i] = chr(ord(L[i])+n)
        T = ''.join(L)
        return T
    
    else :
        L = list(M)

        D = {}
        for i in range (len(M)):
            if M[i] not in D :
                D[M[i]]=0
            D[M[i]]+=1
        
        a = 0
        b = ''
        for k,v in D.items() :
            if v > a :
                a = v
                b = k
        n = ord(b)-ord(' ')

        for i in range (len(L)) :
            L[i] = chr(ord(L[i])-n)
        T = ''.join(L)
        
        return T


M = 'bonjour je suis aurelie et j\'aime les chats mon but est dans devenir un, alors un jour je serait chat'
M1 = cryptDecrypt (M,10000)

cryptDecrypt (M1,0)
# Out:
# "bonjour je suis aurelie et j'aime les chats mon but est dans devenir un, alors un jour je serait chat"

# %%
def trouveK (t):
    verif = False
    p = 1
    
    while verif != True :
        T = []
        C = []
        p += 1
        d = 0
        for i in range (p) :          # sépare le texte
            T.append(couper(p,i,t))
            #print('parti ' + str(i) + ' coupé')
        #print('tout coupé')
        
        for i in range (p) :           # compte occurence
            D = compter(T[i])
            a = 0
            b = ''
            for k,v in D.items() :       # trouve la plus répétée
                if v > a :
                    a = v
                    b = k
            d = ord(b)-ord(' ')        # trouve le décalage
            C.append(d)
            #print('décalage ' + str(C[i]) + ' trouvé')
        #print('décalage complet')

        verif = True

        for i in range (len(C)):          # verifie si decalage possible
            for j in range (len(T[i])) :
                if ((ord(T[i][j])-C[i]) < 0) :   # pas de sens
                    #print('condition fausse')
                    verif = False
                    break
            
    return p

# %%
def CompletK(t):
    x = trouveK(t)
    print(x)
    return(complet(t,x))

# %% [markdown]
# # Exo

# %% [markdown]
# ## Message 6

# %%
import os

with open(r'.\messages\message6.txt', encoding="utf-8") as file:
    M6 = file.read()
# M6

# %%
ord('\n')-51
ord('\n')-ord(' ')
# Out:
# -22

# %%
trouveK(M6)
# Out:
# 13

# %%
print(complet (M6, 13))
# Out:
# Voici un message supplémentaire pour tester que votre algorithme de déchiffrage du code de Vigenère est robuste. On met à nouveau du texte à la suite de ce message pour faciliter l'analyse de fréquence. Le message qui suit est encore encodé avec Vigenère, il sert principalement d'instruction pour le message 8.
#
#
# Chanson d'automne (Paul Verlaine)
#
# Les sanglots longsDes violons
# De l'automne
# Blessent mon coeur
# D'une langueur
# Monotone.
#
# Tout suffocant
# Et blême, quand
# Sonne l'heure,
# Je me souviens
# Des jours anciens
# Et je pleure
#
# Et je m'en vais
# Au vent mauvaisQui m'emporte
# Deçà, delà,Pareil à la
# Feuille morte.
#
# ...

# %%
CompletK(M6)
# Out:
# 13
# ...

# %% [markdown]
# ## Message 7

# %%
import os

with open(r'.\messages\message7.txt', encoding="utf-8") as file:
    M7 = file.read()

# %%
print(CompletK(M7))
# Out:
# 20
# Le message suivant est chiffré en utilisant un algorithme proche de celui utilisé par la machine Enigma, utilisé par l'Allemagne lors de la seconde guerre mondiale.
# Principe de la machine Enigma
# ...
#
# ...
